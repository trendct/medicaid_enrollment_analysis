# %% [markdown]
# # Husky Enrollment by town
#
# Analysis started Friday, March 18, 2016.
#
# ## 0 Data import
#
# ### 0.A Import Husky sheet

# %%
import pandas as pd

## Load HUSKY A tab, skipping header lines
husky = pd.read_excel("HUSKYA and Medicaid by Town with %.xls",
                           sheetname=0,
                           skiprows=6, 
                           names=["town","population","husky_enrollment","husky_pct_enrollment"])

## (Uncomment below) Check that their calculated enrollment percent matches my own (should equal zero)
#husky["calculated_pct"] = husky["enrollment"] / husky["population"]
#husky["calculated_pct"].sum() - husky["pct_enrollment"].sum()


## Add a column for a human-friendly percent
husky["husky_pct"] = husky["husky_pct_enrollment"] * 100

## Drop origin percent col
husky = husky.drop(["husky_pct_enrollment"], 1)

## (Uncomment below) Describe the dataset
#husky.describe()

## (Uncomment below) Count rows
husky.count()
# Out:
# town                170
# population          170
# husky_enrollment    170
# husky_pct           170
# dtype: int64

# %% [markdown]
# ### 0.b Import Medicaid sheet

# %%
## Load Sheet 2
medicaid = pd.read_excel("HUSKYA and Medicaid by Town with %.xls",
                         sheetname="Medicaid Enrollment by Town",
                         skiprows=4,
                         names=["town","population","med_enrollment","drop","med_pct"])

## fourth column is empty
medicaid = medicaid.drop("drop",1)

## drop null rows
medicaid = medicaid[medicaid["population"].notnull()]


## Check that their percentages are correct
#medicaid["calculated_pct"] = medicaid["med_enrollment"] / medicaid["population"]
#medicaid["calculated_pct"].sum() - medicaid["med_pct"].sum()

## Add a human-readable percent column
medicaid["med_pct"] = medicaid["med_pct"] * 100

## Drop original percent column
#medicaid = medicaid.drop("med_pct", 1)

## (Uncomment below) Count rows
medicaid.count()
# Out:
# town              170
# population        170
# med_enrollment    170
# med_pct           170
# dtype: int64

# %% [markdown]
# ### Merge sheets

# %%
combined = medicaid.merge(husky,on=["town","population"])

## Count rows. Should have the same # no of rows as medicaid and husky
combined.count()
# Out:
# town                169
# population          169
# med_enrollment      169
# med_pct             169
# husky_enrollment    169
# husky_pct           169
# dtype: int64

# %%
## Something went wrong. Let's find the row that didn't synch

## Rows in husky but not in combined
#husky[~husky["town"].isin(combined["town"])]

## Rows in medicaid but not in combined
#medicaid[~medicaid["town"].isin(combined["town"])]

# %%
## North stonington is the problem. It's entered both as "No. Stonington" and "North Stonington"
medicaid = medicaid.replace("No. Stonington", "North Stonington")


## Try merge again
combined = medicaid.merge(husky,on=["town","population"])

## Count rows. Should have the same # no of rows as medicaid and husky
combined.count()
# Out:
# town                170
# population          170
# med_enrollment      170
# med_pct             170
# husky_enrollment    170
# husky_pct           170
# dtype: int64

# %%
## Good! Moving on...

# %% [markdown]
# ## 1 Towns with the highest enrollment
#
# Canaan has a population of 1,195, so the percentage each resident accounts for is significantly higher than the other places on the list. We'll look just at towns with populations over 5,000
#
# ### 1.a Top medicaid enrollment

# %% [markdown]
# Canaan has a population of 1,195, so the percentage each resident accounts for is significantly higher than the other places on the list.

# %%
combined[combined["population"] > 5000].sort_values("med_pct", ascending=False).head(10)
# Out:
#               town  population  med_enrollment    med_pct  husky_enrollment  \
# 63        Hartford      124705           71755  57.539794             39917
# 150      Waterbury      109307           55828  51.074497             33099
# 88     New Britain       72878           34049  46.720547             20398
# 14      Bridgeport      147612           66854  45.290356             40457
# 92       New Haven      130282           56711  43.529421             31913
# 93      New London       27374           11716  42.799737              6830
# 162        Windham       25005           10163  40.643871              5682
# 103        Norwich       40178           15467  38.496192              9106
# 41   East Hartford       51033           19261  37.742245             11487
# 79         Meriden       60293           22091  36.639411             13079
#
#      husky_pct
# 63   32.009142
# 150  30.280769
# 88   27.989242
# 14   27.407663
# 92   24.495326
# 93   24.950683
# 162  22.723455
# 103  22.664145
# 41   22.508965
# 79   21.692402

# %% [markdown]
# ### 1.b Top husky enrollment

# %%
combined[combined["population"] > 5000].sort_values("husky_pct", ascending=False).head(10)
# Out:
#               town  population  med_enrollment    med_pct  husky_enrollment  \
# 63        Hartford      124705           71755  57.539794             39917
# 150      Waterbury      109307           55828  51.074497             33099
# 88     New Britain       72878           34049  46.720547             20398
# 14      Bridgeport      147612           66854  45.290356             40457
# 93      New London       27374           11716  42.799737              6830
# 92       New Haven      130282           56711  43.529421             31913
# 162        Windham       25005           10163  40.643871              5682
# 103        Norwich       40178           15467  38.496192              9106
# 41   East Hartford       51033           19261  37.742245             11487
# 79         Meriden       60293           22091  36.639411             13079
#
#      husky_pct
# 63   32.009142
# 150  30.280769
# 88   27.989242
# 14   27.407663
# 93   24.950683
# 92   24.495326
# 162  22.723455
# 103  22.664145
# 41   22.508965
# 79   21.692402

# %%
# Add a column for the share of the husky program 
combined["husky_share"] = combined["husky_enrollment"] * 100 / combined["med_enrollment"]

combined.describe()
# Out:
#            population  med_enrollment     med_pct  husky_enrollment  \
# count      170.000000      170.000000  170.000000        170.000000
# mean     42313.847059     9690.200000   16.583130       5483.376471
# std     275407.148728    63679.145467   10.220578      36057.610465
# min        846.000000       64.000000    3.715826         34.000000
# 25%       5473.250000      683.250000    9.694484        347.500000
# 50%      12821.000000     1477.000000   13.902793        756.000000
# 75%      25938.500000     3960.500000   19.562850       2113.500000
# max    3596677.000000   823867.000000   63.598326     466087.000000
#
#         husky_pct  husky_share
# count  170.000000   170.000000
# mean     9.188307    54.339931
# std      6.085087     6.209408
# min      1.905090    28.302676
# 25%      5.097916    50.191141
# 50%      7.337486    54.551823
# 75%     11.331514    58.729329
# max     32.887029    69.834711

# %% [markdown]
# ### 1.c Town's with the largest share of Husky A enrollment vs. overall medicaid program

# %%
combined[combined["population"] > 5000].sort_values("husky_share", ascending=False).head(10)[["town","husky_share"]]
# Out:
#                  town  husky_share
# 33            Danbury    64.918573
# 116           Redding    64.123711
# 71            Ledyard    64.096715
# 168         Woodstock    63.465160
# 21         Canterbury    63.010753
# 19         Burlington    63.008130
# 57           Griswold    62.915007
# 1             Ansonia    62.469257
# 87          Naugatuck    62.215772
# 101  North Stonington    61.983471

# %% [markdown]
# ### 1.c Town's with the smallest share of Husky A enrollment vs. overall medicaid program

# %%
combined[combined["population"] > 5000].sort_values("husky_share", ascending=True).head(10)[["town","husky_share"]]
# Out:
#            town  husky_share
# 130   Southbury    28.302676
# 160      Wilton    39.492754
# 3          Avon    42.384106
# 155   Westbrook    42.469598
# 7       Bethany    43.198091
# 24     Cheshire    43.450479
# 51   Farmington    43.763756
# 118  Rocky Hill    43.889316
# 114    Prospect    44.585987
# 10   Bloomfield    44.646506

# %% [markdown]
# ### 1.d Section conclusions
#
# 1. The lists with the highest medicaid enrollment and the highest husky A enrollment are virtually identical, with only New London and New Haven switching positions.
# 2. At first glance, the towns with the largest and smallest share of husky enrollment versus total medicaid enrollment seems random. Maybe it is just a proxy for the age of the population. Anecdotally, I think Southbury has a large elderly population.

# %% [markdown]
# ## 2 Comparing age of town populations

# %%
#combined

# %%
age = pd.read_csv("ACS_14_5YR_S0101_with_ann.csv",
                 skiprows=1)
age = age[~age["Geography"].str.contains("County subdivisions not defined")]

age.dtypes

import pprint  
total_cols = [col for col in age.columns if 'Total; Estimate' in col and 'AGE' in col]
#pprint.pprint(total_cols)
#age_totals = age[total_cols]
#age_totals.dtypes

age_medians = age[["Geography","Total; Estimate; SUMMARY INDICATORS - Median age (years)"]]

age_groups = age[["Total; Estimate; AGE - Under 5 years",
     "Total; Estimate; SELECTED AGE CATEGORIES - 5 to 14 years",
     "Total; Estimate; SELECTED AGE CATEGORIES - 15 to 17 years"
    ]]

age_groups.loc[:,
               "under_5"] = pd.to_numeric(age_groups["Total; Estimate; AGE - Under 5 years"])
age_groups.loc[:,
               "5_to_14"] = pd.to_numeric(age_groups["Total; Estimate; SELECTED AGE CATEGORIES - 5 to 14 years"])
age_groups.loc[:,
               "15_to_17"] = pd.to_numeric(age_groups["Total; Estimate; SELECTED AGE CATEGORIES - 15 to 17 years"])
age_groups.loc[:,
             "under_18"] = age_groups["under_5"] + age_groups["5_to_14"] + age_groups["15_to_17"]

age_groups.loc[age["Geography"].notnull(),
                "town"] = age["Geography"].apply(lambda x: x[0:x.find(" town, ")])

age_under_18 = age_groups[["town", "under_18"]]

age_under_18.head()
# Out:
#          town  under_18
# 1      Bethel      22.8
# 2  Bridgeport      25.2
# 3  Brookfield      23.0
# 4     Danbury      21.2
# 5      Darien      33.7

# %%
#combined.head()

# %%
import numpy as np

age_medians.loc[age_medians["Geography"].notnull(),"town"] = age_medians["Geography"].apply(lambda x: x[0:x.find(" town, ")])
age_medians.loc[np.isreal(age_medians["Total; Estimate; SUMMARY INDICATORS - Median age (years)"]),
                                     "median_age"] = pd.to_numeric(age_medians["Total; Estimate; SUMMARY INDICATORS - Median age (years)"])
age_medians_clean = age_medians[["town","median_age"]]

#age_medians.sort_values(by="median_age", ascending=False)[["town","median_age"]]
age_medians_clean.describe()
# Out:
#        median_age
# count  169.000000
# mean    43.550888
# std      4.877208
# min     21.100000
# 25%     41.500000
# 50%     43.800000
# 75%     46.100000
# max     58.600000

# %%
#combined = combined.merge(age_medians_clean,on="town")
combined = combined.merge(age_under_18,on="town")

# %%
combined.corr()
# Out:
#                   population  med_enrollment   med_pct  husky_enrollment  \
# population          1.000000        0.891665  0.524308          0.890324
# med_enrollment      0.891665        1.000000  0.695984          0.998616
# med_pct             0.524308        0.695984  1.000000          0.696863
# husky_enrollment    0.890324        0.998616  0.696863          1.000000
# husky_pct           0.525807        0.699091  0.987432          0.704848
# husky_share         0.086894        0.171036  0.278470          0.195524
# median_age         -0.580746       -0.559031 -0.473650         -0.561162
# under_18            0.108752        0.069922 -0.203857          0.074034
#
#                   husky_pct  husky_share  median_age  under_18
# population         0.525807     0.086894   -0.580746  0.108752
# med_enrollment     0.699091     0.171036   -0.559031  0.069922
# med_pct            0.987432     0.278470   -0.473650 -0.203857
# husky_enrollment   0.704848     0.195524   -0.561162  0.074034
# husky_pct          1.000000     0.410273   -0.511964 -0.160799
# husky_share        0.410273     1.000000   -0.312398  0.073939
# median_age        -0.511964    -0.312398    1.000000 -0.183240
# under_18          -0.160799     0.073939   -0.183240  1.000000

# %%
combined[combined["population"] > 5000].sort_values("husky_share", ascending=False).head(10)[["town","husky_share","median_age"]]
# Out:
#                  town  husky_share  median_age
# 33            Danbury    64.918573        36.8
# 116           Redding    64.123711        48.8
# 71            Ledyard    64.096715        41.4
# 167         Woodstock    63.465160        44.5
# 21         Canterbury    63.010753        43.4
# 19         Burlington    63.008130        42.4
# 57           Griswold    62.915007        37.3
# 1             Ansonia    62.469257        40.8
# 87          Naugatuck    62.215772        38.7
# 101  North Stonington    61.983471        46.9

# %%
combined[combined["population"] > 5000].sort_values("husky_share", ascending=True).head(10)[["town","husky_share","median_age"]]
# Out:
#            town  husky_share  median_age
# 130   Southbury    28.302676        50.1
# 160      Wilton    39.492754        42.2
# 3          Avon    42.384106        45.8
# 155   Westbrook    42.469598        48.9
# 7       Bethany    43.198091        44.6
# 24     Cheshire    43.450479        42.9
# 51   Farmington    43.763756        43.4
# 118  Rocky Hill    43.889316        43.4
# 114    Prospect    44.585987        45.0
# 10   Bloomfield    44.646506        48.2

# %% [markdown]
# ### 2.a Section conclusions
#
# 1. There is no strong correlation between a town's median age and the share of Husky A enrollments compared with overall Medicaid enrollments.

# %% [markdown]
# ## 3 Output for chart

# %%
combined.to_csv("output.csv")

# %%
# Out:
#               town  population  med_enrollment    med_pct  husky_enrollment  \
# 0          Andover        3272             395  12.072127               226
# 1          Ansonia       18959            6099  32.169418              3810
# 2          Ashford        4259             888  20.849965               562
# 3             Avon       18421            1208   6.557733               512
# 4      Barkhamsted        3705             483  13.036437               283
# 5     Beacon Falls        6055             805  13.294798               431
# 6           Berlin       20610            2363  11.465308              1123
# 7          Bethany        5531             419   7.575484               181
# 8           Bethel       19372            2731  14.097667              1596
# 9        Bethlehem        3501             481  13.738932               278
# 10      Bloomfield       20819            4894  23.507373              2185
# 11          Bolton        4952             532  10.743134               300
# 12          Bozrah        2622             441  16.819222               225
# 13        Branford       28225            4522  16.021258              2132
# 14      Bridgeport      147612           66854  45.290356             40457
# 15     Bridgewater        1675             121   7.223881                59
# 16         Bristol       60570           16295  26.902757              9528
# 17      Brookfield       17055            1728  10.131926               984
# 18        Brooklyn        8254            1763  21.359341               934
# 19      Burlington        9576             738   7.706767               465
# 20          Canaan        1195             760  63.598326               393
# 21      Canterbury        5088             930  18.278302               586
# 22          Canton       10345             992   9.589174               471
# 23         Chaplin        2262             478  21.131742               276
# 24        Cheshire       29250            2504   8.560684              1088
# 25         Chester        4316             599  13.878591               245
# 26         Clinton       13129            2170  16.528296              1188
# 27      Colchester       16192            2543  15.705287              1399
# 28       Colebrook        1445              88   6.089965                51
# 29        Columbia        5454             643  11.789512               337
# ..             ...         ...             ...        ...               ...
# 138       Suffield       15814            1221   7.721007               627
# 139      Thomaston        7683            1315  17.115710               687
# 140       Thompson        9308            1766  18.972927              1023
# 141        Tolland       14872            1256   8.445401               691
# 142     Torrington       35190           11219  31.881216              6037
# 143       Trumbull       36578            3908  10.684018              1936
# 144          Union         846              64   7.565012                34
# 145         Vernon       29098            7105  24.417486              3853
# 146      Voluntown        2593             502  19.359815               327
# 147    Wallingford       45074            7216  16.009229              3695
# 148         Warren        1427             117   8.199019                73
# 149     Washington        3487             391  11.213077               227
# 150      Waterbury      109307           55828  51.074497             33099
# 151      Waterford       19427            3193  16.435888              1577
# 152      Watertown       22046            3804  17.254831              1939
# 153  West Hartford       63324            9697  15.313309              4785
# 154     West Haven       54905           16622  30.274110             10085
# 155      Westbrook        6902            1069  15.488264               454
# 156         Weston       10388             386   3.715826               229
# 157       Westport       27561            1428   5.181234               659
# 158   Wethersfield       26446            4039  15.272631              2058
# 159     Willington        5934             733  12.352545               417
# 160         Wilton       18692            1104   5.906270               436
# 161        Windham       25005           10163  40.643871              5682
# 162        Windsor       29069            5638  19.395232              2978
# 163  Windsor Locks       12565            2545  20.254676              1557
# 164        Wolcott       16716            2606  15.589854              1298
# 165     Woodbridge        8925             714   8.000000               343
# 166       Woodbury        9719            1021  10.505196               511
# 167      Woodstock        7860            1062  13.511450               674
#
#      husky_pct  husky_share  median_age  under_18
# 0     6.907090    57.215190        43.0      23.3
# 1    20.095997    62.469257        40.8      22.8
# 2    13.195586    63.288288        41.1      20.7
# 3     2.779437    42.384106        45.8      25.1
# 4     7.638327    58.592133        44.7      22.0
# 5     7.118084    53.540373        43.0      22.1
# 6     5.448811    47.524333        45.7      21.2
# 7     3.272464    43.198091        44.6      24.0
# 8     8.238695    58.440132        42.3      22.8
# 9     7.940588    57.796258        48.9      20.8
# 10   10.495221    44.646506        48.2      14.6
# 11    6.058158    56.390977        47.2      20.5
# 12    8.581236    51.020408        46.5      20.0
# 13    7.553587    47.147280        48.0      17.5
# 14   27.407663    60.515452        32.3      25.2
# 15    3.522388    48.760331        52.3      19.5
# 16   15.730560    58.471924        41.4      20.7
# 17    5.769569    56.944444        44.6      23.0
# 18   11.315726    52.977879        42.3      22.7
# 19    4.855890    63.008130        42.4      26.6
# 20   32.887029    51.710526        51.4      16.2
# 21   11.517296    63.010753        43.4      23.1
# 22    4.552924    47.479839        45.2      22.7
# 23   12.201592    57.740586        42.8      20.1
# 24    3.719658    43.450479        42.9      21.6
# 25    5.676552    40.901503        50.9      19.2
# 26    9.048671    54.746544        44.2      21.1
# 27    8.640069    55.013763        39.2      25.3
# 28    3.529412    57.954545        47.5      18.1
# 29    6.178951    52.410575        48.0      20.7
# ..         ...          ...         ...       ...
# 138   3.964841    51.351351        41.5      19.8
# 139   8.941820    52.243346        43.7      20.3
# 140  10.990546    57.927520        43.0      19.7
# 141   4.646315    55.015924        43.1      25.6
# 142  17.155442    53.810500        44.3      19.3
# 143   5.292799    49.539406        43.4      25.1
# 144   4.018913    53.125000        42.2      22.8
# 145  13.241460    54.229416        40.4      17.5
# 146  12.610875    65.139442        44.4      20.6
# 147   8.197631    51.205654        43.7      20.0
# 148   5.115627    62.393162        50.3      19.1
# 149   6.509894    58.056266        52.0      14.5
# 150  30.280769    59.287454        35.1      25.0
# 151   8.117568    49.389289        47.0      19.8
# 152   8.795246    50.972660        44.5      21.4
# 153   7.556377    49.345158        41.5      22.6
# 154  18.368090    60.672603        36.3      21.5
# 155   6.577804    42.469598        48.9      15.7
# 156   2.204467    59.326425        43.3      33.4
# 157   2.391060    46.148459        45.3      28.6
# 158   7.781895    50.953206        45.3      19.9
# 159   7.027300    56.889495        36.4      18.9
# 160   2.332549    39.492754        42.2      31.4
# 161  22.723455    55.908688        30.7      19.1
# 162  10.244590    52.820149        42.5      21.7
# 163  12.391564    61.178782        42.1      17.9
# 164   7.765016    49.808135        44.7      21.4
# 165   3.843137    48.039216        47.4      23.8
# 166   5.257743    50.048972        47.6      21.3
# 167   8.575064    63.465160        44.5      23.7
#
# [168 rows x 9 columns]

# %%
import json

def hashed_json(dataset,index):
    dataset=json.loads(dataset.to_json(orient="records"))
    ret = {}
    for record in dataset:
        ret[record[index]] = record
        del (ret[record[index]][index])
    return ret

outfh = open ("medicaid.json","w")

outfh.write(json.dumps(hashed_json(combined,"town")))

outfh.close()
